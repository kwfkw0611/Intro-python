# %% [markdown]
# ![logo](https://xccelerate.co/static/logo@3x-45da759fdee2af1d7e8b7cc2c3e8e73e-2c425.png)

# %% [markdown]
# ## Data Analytics with Python -  Data structure & Pandas
#
# The learning objective are
# - Pandas
# - Data Structure - Series, DataFrames, and Reading Data
# - Exploratory data analysis
# - Time Series
#
# [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/10min.html#min) short introduction to pandas
#
# [Official tutorial](https://pandas.pydata.org/pandas-docs/stable/tutorials.html) for pandas

# %% [markdown]
# ## What is Pandas?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Pandas is a library for working with tabular data in python, you can think of it like excel in python. It intergrates smoothly with the rest of the ecosystem like plotting, databases and numpy.
#
# Think of Pandas as a tool that picks functions and code already defined and labored in “NumPy” to save the user to time and space to handle big data. Very simply put Pandas is the cake and NumPy are all the ingredients that need to put together to make that cake. Large scale you need a machine that cranks output instantly rather then hand making the product.
#
# Pandas has it’s root dating back to 2008 that begun it’s inception by a former employee of AQR Capital Management Wes McKinney, who wanted to accelerate quantitative analysis. AQR Capital was generous enough to allow the code to be open sourced.
#
# Pandas library allows us to do data analysis, manipulation and storing very easily in python.
#
# To use Pandas the syntax is
# ```python
# import pandas as pd
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When we call the pandas function `pd.DataFrame()` 'a' would be the columns and 'b' would be the rows.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Another e.g.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Series
# A Pandas Series can take a list, dictionary or numpy array to create a Series object using `pd.Series()`
#
# A Series is a one-dimensional object similar to an array, list, or column in a table. It will assign a labeled index to each item in the Series. By default, each item will receive an index label from 0 to N, where N is the length of the Series minus one
#
# [intro to pandas data structures](https://pandas.pydata.org/pandas-docs/stable/dsintro.html)

# %%
import numpy as np
import pandas as pd

# %%
lst = [11, 24, -5, 12, -8, 19]
arr = np.random.rand(6)
d = {1:'abc', 'a': 19, 'b': 'xyz', 2: 43, 'c': '32fc', '3z': 3.14}
labels = ['A1', 'B1', 'C1', 'D1', 'E1', 'F1']

# %%
# convert array to series
pd.Series(data=arr)
# Out:
# 0    0.228426
# 1    0.610992
# 2    0.788882
# 3    0.349037
# 4    0.488769
# 5    0.638938
# dtype: float64

# %%
# datatype
type(pd.Series(arr))
# Out:
# pandas.core.series.Series

# %%
# convert dictionary to series
# index are dictionary keys
pd.Series(data=d)
# Out:
# 1      abc
# a       19
# b      xyz
# 2       43
# c     32fc
# 3z    3.14
# dtype: object

# %%
# convert list to series
pd.Series(lst)
# Out:
# 0    11
# 1    24
# 2    -5
# 3    12
# 4    -8
# 5    19
# dtype: int64

# %%
# assigning custom index
s = pd.Series(data=lst, index=labels)
s
# Out:
# A1    11
# B1    24
# C1    -5
# D1    12
# E1    -8
# F1    19
# dtype: int64

# %%
pd.Series(lst, d)
# Out:
# 1     11
# a     24
# b     -5
# 2     12
# c     -8
# 3z    19
# dtype: int64

# %% [markdown]
# ### Indexing a Series
# Pandas uses index names or numbers to extract information

# %%
s
# Out:
# A1    11
# B1    24
# C1    -5
# D1    12
# E1    -8
# F1    19
# dtype: int64

# %%
s['A1']
# Out:
# 11

# %%
# selecting multiple index
s[['A1','C1', 'F1']]
# Out:
# A1    11
# C1    -5
# F1    19
# dtype: int64

# %%
s2 = pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'])
s2
# Out:
# 0                7
# 1       Heisenberg
# 2             3.14
# 3      -1789710578
# 4    Happy Eating!
# dtype: object

# %%
s2[[0,2,4]]
# Out:
# 0                7
# 2             3.14
# 4    Happy Eating!
# dtype: object

# %%
s2[1:4]
# Out:
# 1     Heisenberg
# 2           3.14
# 3    -1789710578
# dtype: object

# %%
# boolean index
s[s % 2 == 0]
# Out:
# B1    24
# D1    12
# E1    -8
# dtype: int64

# %% [markdown]
# ### Updating values by index

# %%
print('old value:', s2[0])
s2[0] = 'seven'
print('new value:', s2[0])
# Out:
# old value: 7
# new value: seven

# %%
# changing values by boolean logic
print(s[s % 2 == 1])
print('\n')
s[s % 2 == 1] = 'odd number'
print(s)
# Out:
# A1    11
# C1    -5
# F1    19
# dtype: int64
#
#
# A1    odd number
# B1            24
# C1    odd number
# D1            12
# E1            -8
# F1    odd number
# dtype: object

# %% [markdown]
# ### Math operations with Series

# %%
s = pd.Series(np.random.randint(1,10, 6))
print(s)
# Out:
# 0    3
# 1    9
# 2    1
# 3    3
# 4    5
# 5    3
# dtype: int32

# %%
# subtract values by 4
s - 4
# Out:
# 0   -1
# 1    5
# 2   -3
# 3   -1
# 4    1
# 5   -1
# dtype: int32

# %%
# mutilpy values by .5
s * .5
# Out:
# 0    1.5
# 1    4.5
# 2    0.5
# 3    1.5
# 4    2.5
# 5    1.5
# dtype: float64

# %%
# using numpy function
np.square(s)
# Out:
# 0     9
# 1    81
# 2     1
# 3     9
# 4    25
# 5     9
# dtype: int32

# %%
# series + series
s + pd.Series(arr)
# Out:
# 0    3.228426
# 1    9.610992
# 2    1.788882
# 3    3.349037
# 4    5.488769
# 5    3.638938
# dtype: float64

# %%
# if 2 series don't have the same index will return a NaN value
s + pd.Series(arr, labels)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# A1   NaN
# B1   NaN
# C1   NaN
# D1   NaN
# E1   NaN
# F1   NaN
# dtype: float64

# %%
ser1 = pd.Series(np.random.rand(5),index=['a1', 'b2','c3','d4','e5'])
ser2 = pd.Series(np.random.randint(1,10,5), index=['A1', 'b2', 'c3', 'D4', 'F6'])
print(ser1,ser2, sep='\n')
# Out:
# a1    0.309876
# b2    0.611561
# c3    0.497820
# d4    0.236764
# e5    0.857377
# dtype: float64
# A1    8
# b2    8
# c3    7
# D4    8
# F6    8
# dtype: int32

# %%
ser1+ser2
# Out:
# A1         NaN
# D4         NaN
# F6         NaN
# a1         NaN
# b2    8.611561
# c3    7.497820
# d4         NaN
# e5         NaN
# dtype: float64

# %% [markdown]
# ### DataFrame
# Think of Pandas DataFrame made up of a bunch of Pandas Series objects. To generate a dataframe use `pd.DataFrame()` can take numpy ndarray (structured or homogeneous), dict, or DataFrame. Dict can contain Series, arrays, constants, or list-like objects

# %%
# array to dataframe
df = pd.DataFrame(data=np.random.randint(1,10,24).reshape(6,4), columns = ['A','B','C','D'], index=['a', 'b', 'c','d','e','f'])
df
# Out:
#    A  B  C  D
# a  2  2  5  9
# b  4  1  2  2
# c  7  5  8  3
# d  6  3  6  7
# e  3  4  3  9
# f  4  7  4  9

# %%
# datatype
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# dictionary to dataframe
d = {'a':[123,412,364],'b':[342, 32.234, 76.5], 'c':['5234',253.62, 'def'], 'd':['abc', '15', 'de252'], 'e':['xyz','34.3dqa', 1.2]}
pd.DataFrame(d)
# Out:
#      a        b       c      d        e
# 0  123  342.000    5234    abc      xyz
# 1  412   32.234  253.62     15  34.3dqa
# 2  364   76.500     def  de252      1.2

# %%
d
# Out:
# {'a': [123, 412, 364],
#  'b': [342, 32.234, 76.5],
#  'c': ['5234', 253.62, 'def'],
#  'd': ['abc', '15', 'de252'],
#  'e': ['xyz', '34.3dqa', 1.2]}

# %% [markdown]
# ### Reading Data
#
# Pandas isn't fussy, can pass a path to the csv file or even give it a url to a csv
#
# [pandas input/output docs](http://pandas.pydata.org/pandas-docs/stable/io.html)

# %% [markdown]
# ### CSV

# %%
# reading url link
# sep = ';' means data is separated by ;
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00397/LasVegasTripAdvisorReviews-Dataset.csv", sep=';')
df.head() # inspects the first 5 rows of dataframe
# Out:
#   User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 0          USA           11                  4             13      5
# 1          USA          119                 21             75      3
# 2          USA           36                  9             25      5
# 3           UK           14                  7             14      4
# 4       Canada            5                  5              2      4
#
#   Period of stay Traveler type Pool  Gym Tennis court Spa Casino  \
# 0        Dec-Feb       Friends   NO  YES           NO  NO    YES
# 1        Dec-Feb      Business   NO  YES           NO  NO    YES
# 2        Mar-May      Families   NO  YES           NO  NO    YES
# 3        Mar-May       Friends   NO  YES           NO  NO    YES
# 4        Mar-May          Solo   NO  YES           NO  NO    YES
#
#   Free internet                              Hotel name Hotel stars  \
# 0           YES  Circus Circus Hotel & Casino Las Vegas           3
# 1           YES  Circus Circus Hotel & Casino Las Vegas           3
# 2           YES  Circus Circus Hotel & Casino Las Vegas           3
# 3           YES  Circus Circus Hotel & Casino Las Vegas           3
# 4           YES  Circus Circus Hotel & Casino Las Vegas           3
#
#    Nr. rooms User continent  Member years Review month Review weekday
# 0       3773  North America             9      January       Thursday
# 1       3773  North America             3      January         Friday
# 2       3773  North America             2     February       Saturday
# 3       3773         Europe             6     February         Friday
# 4       3773  North America             7        March        Tuesday

# %% [markdown]
# ### CSV write

# %%
df.to_csv('filename', index=False)

# %% [markdown]
# ### excel

# %%
# reading excel to dataframe
df_excel = pd.read_excel('https://www.censtatd.gov.hk/fd.jsp?file=D5600551B2018MM11B.xlsx&product_id=D5600551',header=8)
df_excel.head()
# Out:
#    Year  Month Unnamed: 2  Africa  The Americas  South Pacific     Europe  \
# 0   NaN    NaN        NaN     NaN           NaN            NaN        NaN
# 1  2011    NaN        NaN  193631     1821096.0       757871.0  1801343.0
# 2  2012    NaN        NaN  173927     1777842.0       740795.0  1867715.0
# 3  2013    NaN        NaN  168656     1665562.0       717419.0  1893726.0
# 4  2014    NaN        NaN  166563     1679083.0       715479.0  1863271.0
#
#    Middle East  North Asia  Southeast Asia     Taiwan    of China      Macao  \
# 0          NaN         NaN             NaN        NaN         NaN        NaN
# 1     199345.0   2304683.0       3751149.0  2148733.0  28100129.0   843330.0
# 2     186352.0   2333060.0       3651803.0  2088745.0  34911395.0   882942.0
# 3     191299.0   2140576.0       3717976.0  2100098.0  40745277.0   957866.0
# 4     188548.0   2329813.0       3614789.0  2031883.0  47247675.0  1001502.0
#
#   Unnamed: 13 Not identified Unnamed: 15       Total
# 0         NaN            NaN         NaN         NaN
# 1         (1)              -         (1)  41921310.0
# 2         NaN            537         NaN  48615113.0
# 3         NaN            349         NaN  54298804.0
# 4         NaN            230         NaN  60838836.0

# %% [markdown]
# ### excel write

# %%
df_excel.to_excel('excel_filename.xlsx', sheetname='Sheet1')

# %% [markdown]
# ### html

# %%
# read a html data table to a list of dataframe
df_html = pd.read_html('https://finance.yahoo.com/quote/%5EGSPC/history?p=%5EGSPC')
df_html[0].tail() # index first element of the list and .tail() inspects the last 5 rows of a dataframe
# Out:
#                                                   Date     Open     High  \
# 96                                        Aug 30, 2018  2908.94  2912.46
# 97                                        Aug 29, 2018  2900.62  2916.50
# 98                                        Aug 28, 2018  2901.45  2903.77
# 99                                        Aug 27, 2018  2884.69  2898.25
# 100  *Close price adjusted for splits.**Adjusted cl...      NaN      NaN
#
#          Low   Close*  Adj Close**        Volume
# 96   2895.22  2901.13      2901.13  2.802180e+09
# 97   2898.40  2914.04      2914.04  2.791860e+09
# 98   2893.50  2897.52      2897.52  2.683190e+09
# 99   2884.69  2896.74      2896.74  2.854080e+09
# 100      NaN      NaN          NaN           NaN

# %% [markdown]
# ### SQL

# %%
from sqlalchemy import create_engine # import engine to connect to sql database
engine = create_engine('sqlite:///:memory:') # access data stored in memory for this example, realworld pass in 'sqlite:///database_name'
df.to_sql('data', engine) # convert existing df in memory to sql
df_sql = pd.read_sql('data', con=engine) # read sql data to dataframe

# %%
df_sql.tail()
# Out:
#      index User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 499    499           UK           15                  4              8      5
# 500    500       Canada           50                 13             29      4
# 501    501          USA          154                 23             31      4
# 502    502          USA            9                  6              5      2
# 503    503          USA           20                 19            112      4
#
#     Period of stay Traveler type Pool  Gym      ...        Spa Casino  \
# 499        Sep-Nov       Couples  YES  YES      ...        YES    YES
# 500        Sep-Nov       Couples  YES  YES      ...        YES    YES
# 501        Sep-Nov       Friends  YES  YES      ...        YES    YES
# 502        Dec-Feb      Families  YES  YES      ...        YES    YES
# 503        Dec-Feb      Families  YES  YES      ...        YES    YES
#
#     Free internet                               Hotel name Hotel stars  \
# 499           YES  The Westin las Vegas Hotel Casino & Spa           4
# 500           YES  The Westin las Vegas Hotel Casino & Spa           4
# 501           YES  The Westin las Vegas Hotel Casino & Spa           4
# 502           YES  The Westin las Vegas Hotel Casino & Spa           4
# 503           YES  The Westin las Vegas Hotel Casino & Spa           4
#
#     Nr. rooms  User continent Member years  Review month Review weekday
# 499       826          Europe            1       October         Sunday
# 500       826   North America            8      November       Thursday
# 501       826   North America            4      November       Thursday
# 502       826   North America            9      December      Wednesday
# 503       826   North America            5      December        Tuesday
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Pandas methods to verify input

# %% [markdown]
# ### head
# `.head()` returns first n number of rows, default is 5

# %%
df.head()
# Out:
#   User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 0          USA           11                  4             13      5
# 1          USA          119                 21             75      3
# 2          USA           36                  9             25      5
# 3           UK           14                  7             14      4
# 4       Canada            5                  5              2      4
#
#   Period of stay Traveler type Pool  Gym Tennis court Spa Casino  \
# 0        Dec-Feb       Friends   NO  YES           NO  NO    YES
# 1        Dec-Feb      Business   NO  YES           NO  NO    YES
# 2        Mar-May      Families   NO  YES           NO  NO    YES
# 3        Mar-May       Friends   NO  YES           NO  NO    YES
# 4        Mar-May          Solo   NO  YES           NO  NO    YES
#
#   Free internet                              Hotel name Hotel stars  \
# 0           YES  Circus Circus Hotel & Casino Las Vegas           3
# 1           YES  Circus Circus Hotel & Casino Las Vegas           3
# 2           YES  Circus Circus Hotel & Casino Las Vegas           3
# 3           YES  Circus Circus Hotel & Casino Las Vegas           3
# 4           YES  Circus Circus Hotel & Casino Las Vegas           3
#
#    Nr. rooms User continent  Member years Review month Review weekday
# 0       3773  North America             9      January       Thursday
# 1       3773  North America             3      January         Friday
# 2       3773  North America             2     February       Saturday
# 3       3773         Europe             6     February         Friday
# 4       3773  North America             7        March        Tuesday

# %% [markdown]
# ### tail
# `.tail()` returns last n number of rows, default 5

# %%
df.tail()
# Out:
#     User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 499           UK           15                  4              8      5
# 500       Canada           50                 13             29      4
# 501          USA          154                 23             31      4
# 502          USA            9                  6              5      2
# 503          USA           20                 19            112      4
#
#     Period of stay Traveler type Pool  Gym Tennis court  Spa Casino  \
# 499        Sep-Nov       Couples  YES  YES           NO  YES    YES
# 500        Sep-Nov       Couples  YES  YES           NO  YES    YES
# 501        Sep-Nov       Friends  YES  YES           NO  YES    YES
# 502        Dec-Feb      Families  YES  YES           NO  YES    YES
# 503        Dec-Feb      Families  YES  YES           NO  YES    YES
#
#     Free internet                               Hotel name Hotel stars  \
# 499           YES  The Westin las Vegas Hotel Casino & Spa           4
# 500           YES  The Westin las Vegas Hotel Casino & Spa           4
# 501           YES  The Westin las Vegas Hotel Casino & Spa           4
# 502           YES  The Westin las Vegas Hotel Casino & Spa           4
# 503           YES  The Westin las Vegas Hotel Casino & Spa           4
#
#      Nr. rooms User continent  Member years Review month Review weekday
# 499        826         Europe             1      October         Sunday
# 500        826  North America             8     November       Thursday
# 501        826  North America             4     November       Thursday
# 502        826  North America             9     December      Wednesday
# 503        826  North America             5     December        Tuesday

# %% [markdown]
# ### info
# `.info()` print a concise summary of dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 20 columns):
# User country         504 non-null object
# Nr. reviews          504 non-null int64
# Nr. hotel reviews    504 non-null int64
# Helpful votes        504 non-null int64
# Score                504 non-null int64
# Period of stay       504 non-null object
# Traveler type        504 non-null object
# Pool                 504 non-null object
# Gym                  504 non-null object
# Tennis court         504 non-null object
# Spa                  504 non-null object
# Casino               504 non-null object
# Free internet        504 non-null object
# Hotel name           504 non-null object
# Hotel stars          504 non-null object
# Nr. rooms            504 non-null int64
# User continent       504 non-null object
# Member years         504 non-null int64
# Review month         504 non-null object
# Review weekday       504 non-null object
# dtypes: int64(6), object(14)
# memory usage: 78.8+ KB

# %% [markdown]
# ## Selecting
# ### columns
# `.columns()` return a list of the column names

# %%
df.columns
# Out:
# Index(['User country', 'Nr. reviews', 'Nr. hotel reviews', 'Helpful votes',
#        'Score', 'Period of stay', 'Traveler type', 'Pool', 'Gym',
#        'Tennis court', 'Spa', 'Casino', 'Free internet', 'Hotel name',
#        'Hotel stars', 'Nr. rooms', 'User continent', 'Member years',
#        'Review month', 'Review weekday'],
#       dtype='object')

# %% [markdown]
# ### index
# `.index` return a immutable index object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=504, step=1)

# %%
# extracting a dataframe column
# index like a extracting a dictionary value
df['Score'].head() # to save notebook space will use .head()
# Out:
# 0    5
# 1    3
# 2    5
# 3    4
# 4    4
# Name: Score, dtype: int64

# %%
# alternativte using dot syntax
df.Score.head()
# Out:
# 0    5
# 1    3
# 2    5
# 3    4
# 4    4
# Name: Score, dtype: int64

# %%
# index by integer [rows,cols]
df.iloc[:, 4].head()
# Out:
# 0    5
# 1    3
# 2    5
# 3    4
# 4    4
# Name: Score, dtype: int64

# %%
print('the datatype:',type(df['Score']))
# Out:
# the datatype: <class 'pandas.core.series.Series'>

# %%
# multiple columns
df[['Score', 'Hotel name']].head()
# Out:
#    Score                              Hotel name
# 0      5  Circus Circus Hotel & Casino Las Vegas
# 1      3  Circus Circus Hotel & Casino Las Vegas
# 2      5  Circus Circus Hotel & Casino Las Vegas
# 3      4  Circus Circus Hotel & Casino Las Vegas
# 4      4  Circus Circus Hotel & Casino Las Vegas

# %%
# more than 1 series becomes a dataframe
print('the dataype:', type(df[['Score', 'Hotel name']]))
# Out:
# the dataype: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Rows
# Selecting whole rows

# %%
df[10:18].head()
# Out:
#    User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 10          USA          102                 24             58      2
# 11    Australia           20                  9             24      3
# 12          USA            7                  6              9      2
# 13          USA           22                  5             13      3
# 14           UK            3                  3              0      3
#
#    Period of stay Traveler type Pool  Gym Tennis court Spa Casino  \
# 10        Jun-Aug      Families   NO  YES           NO  NO    YES
# 11        Jun-Aug       Friends   NO  YES           NO  NO    YES
# 12        Jun-Aug       Friends   NO  YES           NO  NO    YES
# 13        Jun-Aug       Friends   NO  YES           NO  NO    YES
# 14        Jun-Aug       Friends   NO  YES           NO  NO    YES
#
#    Free internet                              Hotel name Hotel stars  \
# 10           YES  Circus Circus Hotel & Casino Las Vegas           3
# 11           YES  Circus Circus Hotel & Casino Las Vegas           3
# 12           YES  Circus Circus Hotel & Casino Las Vegas           3
# 13           YES  Circus Circus Hotel & Casino Las Vegas           3
# 14           YES  Circus Circus Hotel & Casino Las Vegas           3
#
#     Nr. rooms User continent  Member years Review month Review weekday
# 10       3773  North America             9         June         Friday
# 11       3773        Oceania             4         June       Saturday
# 12       3773  North America             1         July      Wednesday
# 13       3773  North America             1         July       Thursday
# 14       3773         Europe             1       August         Sunday

# %%
# last 4 rows
df[-4:].head()
# Out:
#     User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 500       Canada           50                 13             29      4
# 501          USA          154                 23             31      4
# 502          USA            9                  6              5      2
# 503          USA           20                 19            112      4
#
#     Period of stay Traveler type Pool  Gym Tennis court  Spa Casino  \
# 500        Sep-Nov       Couples  YES  YES           NO  YES    YES
# 501        Sep-Nov       Friends  YES  YES           NO  YES    YES
# 502        Dec-Feb      Families  YES  YES           NO  YES    YES
# 503        Dec-Feb      Families  YES  YES           NO  YES    YES
#
#     Free internet                               Hotel name Hotel stars  \
# 500           YES  The Westin las Vegas Hotel Casino & Spa           4
# 501           YES  The Westin las Vegas Hotel Casino & Spa           4
# 502           YES  The Westin las Vegas Hotel Casino & Spa           4
# 503           YES  The Westin las Vegas Hotel Casino & Spa           4
#
#      Nr. rooms User continent  Member years Review month Review weekday
# 500        826  North America             8     November       Thursday
# 501        826  North America             4     November       Thursday
# 502        826  North America             9     December      Wednesday
# 503        826  North America             5     December        Tuesday

# %% [markdown]
# ### Rows and Columns
# To select both rows and columns use `.iloc[,]`. In the bracket the first entry before the comma is row and after the comma is column

# %%
df.iloc[100:106, 3:8]
# Out:
#      Helpful votes  Score Period of stay Traveler type Pool
# 100              8      4        Mar-May      Business  YES
# 101              9      4        Mar-May       Couples  YES
# 102             28      5        Mar-May       Couples  YES
# 103            103      4        Mar-May      Business  YES
# 104              0      4        Mar-May       Couples  YES
# 105             31      3        Mar-May       Friends  YES

# %%
# Alternative method
df[11:14][['Hotel name','Score']]
# Out:
#                                 Hotel name  Score
# 11  Circus Circus Hotel & Casino Las Vegas      3
# 12  Circus Circus Hotel & Casino Las Vegas      2
# 13  Circus Circus Hotel & Casino Las Vegas      3

# %% [markdown]
# ### Conditionals
# Use boolean to filter

# %%
# filter where 'Score' is >= 4
df[df['Score'] >=4].head()
# Out:
#   User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 0          USA           11                  4             13      5
# 2          USA           36                  9             25      5
# 3           UK           14                  7             14      4
# 4       Canada            5                  5              2      4
# 6           UK           45                 12             46      4
#
#   Period of stay Traveler type Pool  Gym Tennis court Spa Casino  \
# 0        Dec-Feb       Friends   NO  YES           NO  NO    YES
# 2        Mar-May      Families   NO  YES           NO  NO    YES
# 3        Mar-May       Friends   NO  YES           NO  NO    YES
# 4        Mar-May          Solo   NO  YES           NO  NO    YES
# 6        Mar-May       Couples   NO  YES           NO  NO    YES
#
#   Free internet                              Hotel name Hotel stars  \
# 0           YES  Circus Circus Hotel & Casino Las Vegas           3
# 2           YES  Circus Circus Hotel & Casino Las Vegas           3
# 3           YES  Circus Circus Hotel & Casino Las Vegas           3
# 4           YES  Circus Circus Hotel & Casino Las Vegas           3
# 6           YES  Circus Circus Hotel & Casino Las Vegas           3
#
#    Nr. rooms User continent  Member years Review month Review weekday
# 0       3773  North America             9      January       Thursday
# 2       3773  North America             2     February       Saturday
# 3       3773         Europe             6     February         Friday
# 4       3773  North America             7        March        Tuesday
# 6       3773         Europe             4        April         Friday

# %%
# multiple filter where 'Score' is >= 4 and 'Nr. reviews' is > 100
df[(df['Score'] >= 4) & (df['Nr. reviews'] > 100)].head()
# Out:
#     User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 15    New Zeland          146                 17             33      4
# 25           USA          114                 42             52      4
# 38           USA          290                263            299      4
# 106           UK          130                 41             61      4
# 121          USA          161                 33             85      4
#
#     Period of stay Traveler type Pool  Gym Tennis court  Spa Casino  \
# 15         Jun-Aug      Families   NO  YES           NO   NO    YES
# 25         Dec-Feb      Business  YES  YES           NO  YES    YES
# 38         Jun-Aug       Couples  YES  YES           NO  YES    YES
# 106        Jun-Aug      Business  YES  YES          YES  YES    YES
# 121        Dec-Feb       Couples  YES  YES           NO  YES    YES
#
#     Free internet                                         Hotel name  \
# 15            YES             Circus Circus Hotel & Casino Las Vegas
# 25            YES                           Excalibur Hotel & Casino
# 38            YES                           Excalibur Hotel & Casino
# 106           YES  Tropicana Las Vegas - A Double Tree by Hilton ...
# 121           YES                                     Caesars Palace
#
#     Hotel stars  Nr. rooms User continent  Member years Review month  \
# 15            3       3773        Oceania             2       August
# 25            3       3981  North America            11      January
# 38            3       3981  North America            10       August
# 106           4       1467         Europe             3         June
# 121           5       3348  North America             3      January
#
#     Review weekday
# 15        Saturday
# 25        Saturday
# 38          Monday
# 106        Tuesday
# 121         Friday

# %%
# filter using variable assignment
score = df['Score'] >= 4
user_country = df['User country'] == 'USA'
df[score | user_country].head()
# Out:
#   User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 0          USA           11                  4             13      5
# 1          USA          119                 21             75      3
# 2          USA           36                  9             25      5
# 3           UK           14                  7             14      4
# 4       Canada            5                  5              2      4
#
#   Period of stay Traveler type Pool  Gym Tennis court Spa Casino  \
# 0        Dec-Feb       Friends   NO  YES           NO  NO    YES
# 1        Dec-Feb      Business   NO  YES           NO  NO    YES
# 2        Mar-May      Families   NO  YES           NO  NO    YES
# 3        Mar-May       Friends   NO  YES           NO  NO    YES
# 4        Mar-May          Solo   NO  YES           NO  NO    YES
#
#   Free internet                              Hotel name Hotel stars  \
# 0           YES  Circus Circus Hotel & Casino Las Vegas           3
# 1           YES  Circus Circus Hotel & Casino Las Vegas           3
# 2           YES  Circus Circus Hotel & Casino Las Vegas           3
# 3           YES  Circus Circus Hotel & Casino Las Vegas           3
# 4           YES  Circus Circus Hotel & Casino Las Vegas           3
#
#    Nr. rooms User continent  Member years Review month Review weekday
# 0       3773  North America             9      January       Thursday
# 1       3773  North America             3      January         Friday
# 2       3773  North America             2     February       Saturday
# 3       3773         Europe             6     February         Friday
# 4       3773  North America             7        March        Tuesday

# %% [markdown]
# # Combining dataframes
# Pandas provides functions for combining dataframes or series.
#
# [official pandas merge doc](https://pandas.pydata.org/pandas-docs/stable/merging.html#)

# %%
data1 = {'id': [1,2,3,4,5],
         'item': ['pen', 'paper', 'folder', 'desk', 'stapler'],
         'price' : [0.49, 0.15, 1.99, 100, 5]}
df1 = pd.DataFrame(data1)
df1
# Out:
#    id     item   price
# 0   1      pen    0.49
# 1   2    paper    0.15
# 2   3   folder    1.99
# 3   4     desk  100.00
# 4   5  stapler    5.00

# %%
data2 = {'id': [1,3,4,6,7],
         'item_id': ['a1', 'a2', 'a3', 'a4', 'a5'],
         'buyer': ['Ralph', 'Joe', 'Gricelda', 'Gricelda', 'Joe']}

df2 = pd.DataFrame(data2)
df2
# Out:
#    id item_id     buyer
# 0   1      a1     Ralph
# 1   3      a2       Joe
# 2   4      a3  Gricelda
# 3   6      a4  Gricelda
# 4   7      a5       Joe

# %% [markdown]
# ### Concatenation
# `pd.concat()` concatenate pandas along on an axis, pass dataframes as a list

# %%
# concat row wise by default
pd.concat([df1,df2], sort='False')
# Out:
#       buyer  id     item item_id   price
# 0       NaN   1      pen     NaN    0.49
# 1       NaN   2    paper     NaN    0.15
# 2       NaN   3   folder     NaN    1.99
# 3       NaN   4     desk     NaN  100.00
# 4       NaN   5  stapler     NaN    5.00
# 0     Ralph   1      NaN      a1     NaN
# 1       Joe   3      NaN      a2     NaN
# 2  Gricelda   4      NaN      a3     NaN
# 3  Gricelda   6      NaN      a4     NaN
# 4       Joe   7      NaN      a5     NaN

# %%
# concat column wise
pd.concat([df1,df2], axis=1)
# Out:
#    id     item   price  id item_id     buyer
# 0   1      pen    0.49   1      a1     Ralph
# 1   2    paper    0.15   3      a2       Joe
# 2   3   folder    1.99   4      a3  Gricelda
# 3   4     desk  100.00   6      a4  Gricelda
# 4   5  stapler    5.00   7      a5       Joe

# %% [markdown]
# ### Merge
# `pd.merge()` merge DataFrame objects by performing a database-style join operation by columns or indexes.

# %%
# default is inner join, merge on 'id'
pd.merge(df1,df2, on='id')
# Out:
#    id    item   price item_id     buyer
# 0   1     pen    0.49      a1     Ralph
# 1   3  folder    1.99      a2       Joe
# 2   4    desk  100.00      a3  Gricelda

# %%
# outer join on 'id'
pd.merge(df1,df2, how='outer', on='id')
# Out:
#    id     item   price item_id     buyer
# 0   1      pen    0.49      a1     Ralph
# 1   2    paper    0.15     NaN       NaN
# 2   3   folder    1.99      a2       Joe
# 3   4     desk  100.00      a3  Gricelda
# 4   5  stapler    5.00     NaN       NaN
# 5   6      NaN     NaN      a4  Gricelda
# 6   7      NaN     NaN      a5       Joe

# %%
# alternative syntax
df1.merge(df2, on = 'id')
# Out:
#    id    item   price item_id     buyer
# 0   1     pen    0.49      a1     Ralph
# 1   3  folder    1.99      a2       Joe
# 2   4    desk  100.00      a3  Gricelda

# %% [markdown]
# ### Join
# `pd.join()` join columns with other DataFrame either on index or on a key column

# %%
# set index on a common df column to join on
df1.set_index('id').join(df2.set_index('id'))
# Out:
#        item   price item_id     buyer
# id
# 1       pen    0.49      a1     Ralph
# 2     paper    0.15     NaN       NaN
# 3    folder    1.99      a2       Joe
# 4      desk  100.00      a3  Gricelda
# 5   stapler    5.00     NaN       NaN

# %%
# join df on their index, if df have identical column name pass lsuffix and rsuffix parameters
df1.join(df2, lsuffix='_df1', rsuffix='_df2' )
# Out:
#    id_df1     item   price  id_df2 item_id     buyer
# 0       1      pen    0.49       1      a1     Ralph
# 1       2    paper    0.15       3      a2       Joe
# 2       3   folder    1.99       4      a3  Gricelda
# 3       4     desk  100.00       6      a4  Gricelda
# 4       5  stapler    5.00       7      a5       Joe

# %% [markdown]
# ## Helpful links
# [Cheat sheet](http://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) for pandas
#
# [Data Structure](https://github.com/yinpatt/DS_HK_7/blob/gh-pages/notebooks/08%20-%20Data%20Wrangling.ipynb)
